# %% [markdown]
# # Eejercicos con la clase Nodo
#
# - Crear un nodo
#     - imprimir el valor del nodo
# - Crear dos nodos 10,20
#  - imprimir el valor del primero
#  - imprimir el valor del segundo
#  - transversal
# - Lo mismo pero con 4 nodos 10,20,30,40
#  - imprimir el valor del primero
#  - imprimir el valor del ultimo
#  - transversal
#  - insertar el nodo 25, despues del nodo 20 y antes del nodo 30
#
#  # Todo esto antes de ir a la escritura formal del ADT Lista ligada.

# %%
class Nodo:
    def __init__(self , value , siguiente = None ):
        self.data = value 
        self.next = siguiente

# %%
head = Nodo(10)
print( head.data )
# Out:
# 10

# %%
head = Nodo (10)
head.next = Nodo(20)
print(f"Primero={ head.data }")
print(f"Segundo={ head.next.data }")

# lo mismo pero ahorrando codigo
#head = Nodo ( 10 , 20)
#print(f"Primero={ head.data }")
#print(f"Segundo={ head.next.data }")

# transversal
curr_node = head
while curr_node != None:
    print(f"| {curr_node.data } | --> " , end="" )
    curr_node = curr_node.next
# Out:
# Primero=10
# Segundo=20
# | 10 | --> | 20 | -->

# %%
head = Nodo(10,Nodo(20, Nodo(30,Nodo(40))))
# transversal
curr_node = head
while curr_node != None:
    print(f"| {curr_node.data } | --> " , end="" ) 
    curr_node = curr_node.next


#imprimir el primero 
print(head.data)
#imprimir el ultimo 
curr_node = head 
while curr_node.next != None:
    print(f"| { curr_node.data } | --> " , end="" )
    curr_node = curr_node.next 
print(curr_node.data)

# insertar el nodo 25, despues del nodo 20 y antes 
curr_node = head
while curr_node.data != 20:
    curr_node = curr_node.next
print(curr_node.data)

# crear el nodo 25 
curr_node = Node(25,curr_node.next)
# Out:
# | 10 | --> | 20 | --> | 30 | --> | 40 | --> 10
# | 10 | --> | 20 | --> | 30 | --> 40
# 20

# %%
a = 10
b = 20
c = 15
c = c + a
# c?

c = (c + a ) * b
print(c)

# %%
class Nodo:
    def __init__(self , value , siguiente = None ):
        self.data = value 
        self.next = siguiente

# %%
class LinkedList:
    def __init__( self ):
        self.head = None 

    def is_empty( self ): # true o false 
        return self.head == None

    def get_tail( self ):
        if self.is_empty():
            return None
        else:
            curr_node = self.head
            while curr_node.next != None:
                curr_node = curr_node.next
            return curr_node.next = Nodo(value)

    def append( self , value ):
        if self.head == None:
            self.head = Nodo( value)
        else:
            curr_node =self.head
            while curr_node.next != None:
                curr_node = curr_node







    def transversal( self ):
        curr_node = self.head
        while curr_node !=None:
            print(f"| {curr})

















    def prepend(self , value ):
        if self.head != None:
            print("Esta vacio , no se puede hacer preppend")
            else:
                aux =
                self.head = Nodo( value , self.head.next )

# %%
lista = LinkedList()
if lista.is_empty():
    print("La lista esta vacia")
else:
    print("La lista no esta vacia")

lista.append(10)
lista.append(20)
lista.append(30)
lista.append(40)
nodo = lista.get_tail()
if nodo != None : 
    print(nodo.data)
else:
    print("Lista esta vacia")
id
# Out:
# La lista esta vacia
# Lista esta vacia
