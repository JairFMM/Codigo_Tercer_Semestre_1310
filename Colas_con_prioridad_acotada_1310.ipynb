# %%
#Implementacion de la cola de prioridad acotada

class BoundedPriorityQueue:
    def __init__( self , niveles ):
        self.data = [ Queue() for x in range (niveles) ]
        #self._data = Array(niveles)
        #self._data.clear( Queue() )
        self._size = 0 #El numero de elementos

    def is_empty( self ):
        return self.__size == 0





    def enqueue 















    def

# %%
salvavidas.enqueue( 3)

# %%
# implementacion de las colas de prioridad sin acotamiento 

class PriorityQueue:
    def __init__( self ): 
        self.__data ={}
        self.__size = 0

    def is_empty( self ):
        return self.__size == 0 

    def length( self ):
        return self._size 

    def enqueue(self , prioridad , elem ):
        existe = False 
        index = 0 
        for indice in range(len(self.__data)):
            if colas[ "prioridad" ] == prioridad:
                existe = True
                indice = index

        if existe: 
            self.__data[indice].enqueue(elem)
        else:
            self.__data.append( {"prioridad":prioridad , "cola" : Queue()})
            self.__data[-1]["cola"].enqueue(elem)

    def to string ( self ):
        for cola in self.__data:
            cola["cola"].to_string()

# %%
cp = PriorityQueue()
cp.enqueue(1, "niñas")
cp.enqueue(2, "niños")
cp.enqueue(2, "Profesores")

cp.to_string()
